# %%
def load_reviews(path) -> list:
    import json
    reviews = list()

    with open(path, 'r', encoding="ISO-8859-1") as file:
        while file.readline():
            try:
                reviews.append(json.loads(file.readline()))
            except:
                continue

    return reviews

# %%
reviews = load_reviews('reviewSelected100.json')

# %%
import spacy
import en_core_web_sm
from spacy import displacy

# %%
nlp = en_core_web_sm.load()
doc = nlp(reviews[0]['text'])

# %%
root = [token for token in doc if token.head == token]
print(root)
root = [token for token in doc if token.head == token][6]

subject = list(root.lefts)[0]
for descendant in subject.subtree:
    assert subject is descendant or subject.is_ancestor(descendant)
    print(descendant.text, descendant.pos_, descendant.dep_, descendant.n_lefts,
            descendant.n_rights,
            [ancestor.text for ancestor in descendant.ancestors])
object_= list(root.rights)[0]

print(root.text)

for descendant in object_.subtree:
    assert object_ is descendant or object_.is_ancestor(descendant)
    print(descendant.text, descendant.pos_, descendant.dep_, descendant.n_lefts,
            descendant.n_rights,
            [ancestor.text for ancestor in descendant.ancestors])
   # if descendant.pos_ == 'NOUN' and 
   # for ancestor in descendant.ancestors:
   #     if ancestor.subtree:
   #         print([e.text for e in ancestor.subtree])
# Out:
# [has, feels, is, forgotten, are, believe, is, is, is, is, have, is]
# To PART aux 0 0 ['start', 'is']
# start VERB advcl 1 0 ['is']
# is
# a DET det 0 0 ['variety', 'is']
# huge ADJ amod 0 0 ['variety', 'is']
# variety NOUN attr 2 3 ['is']
# of ADP prep 0 1 ['variety', 'is']
# sushi NOUN pobj 0 2 ['of', 'variety', 'is']
# , PUNCT punct 0 0 ['sushi', 'of', 'variety', 'is']
# sashimi NOUN conj 0 2 ['sushi', 'of', 'variety', 'is']
# and CCONJ cc 0 0 ['sashimi', 'sushi', 'of', 'variety', 'is']
# maki NOUN conj 0 0 ['sashimi', 'sushi', 'of', 'variety', 'is']
# , PUNCT punct 0 0 ['variety', 'is']
# ranging VERB acl 0 1 ['variety', 'is']
# from ADP prep 0 2 ['ranging', 'variety', 'is']
# the DET det 0 0 ['traditional', 'from', 'ranging', 'variety', 'is']
# traditional ADJ pobj 1 0 ['from', 'ranging', 'variety', 'is']
# to ADP prep 0 1 ['from', 'ranging', 'variety', 'is']
# on ADP nmod 0 2 ['creations', 'to', 'from', 'ranging', 'variety', 'is']
# - PUNCT punct 0 0 ['on', 'creations', 'to', 'from', 'ranging', 'variety', 'is']
# the DET det 0 0 ['spot', 'on', 'creations', 'to', 'from', 'ranging', 'variety', 'is']
# - PUNCT punct 0 0 ['spot', 'on', 'creations', 'to', 'from', 'ranging', 'variety', 'is']
# spot NOUN pobj 2 0 ['on', 'creations', 'to', 'from', 'ranging', 'variety', 'is']
# creations NOUN pobj 1 0 ['to', 'from', 'ranging', 'variety', 'is']

# %%
displacy.render(doc, style="dep")
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="64baf2c34fe84dad82abc657ae941adb-0" class="displacy" width="38725" height="1537.0" direction="ltr" style="max-width: none; height: 1537.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">place</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">favourite</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">all</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">eat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">sushi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">place,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">they</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">great</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">job</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">carte</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">too.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">location</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">feels</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">nicer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">than</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300">ADP</tspan>
# </text>
#
# <te

# %%
print(doc)
# Out:
# This place has to be my favourite all you can eat sushi place, and  they do a great job with a la carte too.
#
# This location feels nicer than the Queen West location. It isn't so brightly lit, and is quieter- conspicuously absent are the same 10  muzak tracks playing on repeat. They also have a checklist ordering system, so fewer items are forgotten or "forgotten". The rolls are also slightly different than the Queen location, with some choices added, some taken away, and others formulated differently. I believe that they use a different teriyaki sauce as well.
#
# To start, there is a huge variety of sushi, sashimi and maki, ranging from the traditional to on-the-spot creations. The Fire House Roll (tuna, tempura shrimp, spicy mayo and mango) is surprisingly delicious. The Cowboy Roll (beef and green onion) is delicious too. The fish is quite fresh, as are the grilled meats, and the seaweed salad is awesome too.
#
# A la carte, you have more choices, and the rolls are more carefully crafted (the AYCE ones can be somewhat rice heavy, although not as much as other locations and restaurants).
#
# Overall, Aji Sai is great food in  a great environment, and an excellent value for your money!http://www.yelp.ca/writeareview/biz/cPzIic1AqH1ApTVVaww5hw?return_url=%2Fuser_details_reviews_self%3Fuserid%3DyGuE8QzNotZCFirfweR1Fg%26rec_pagestart%3D0&review_id=g3WPH7aUTT1cUrx3vw5AuQ#

# %%
[e for e in doc if e.dep_ == 'ROOT']
# Out:
# [has, feels, is, forgotten, are, believe, is, is, is, is, have, is]

# %%
doc[4]
# Out:
# be

# %%
test = nlp("The variety was huge and the service was so bad")
for e in test:
    print(e.text, e.pos_, e.head, e.head.head, e.dep_, [ancestor.text for ancestor in e.ancestors])
# Out:
# The DET variety was det ['variety', 'was']
# variety NOUN was was nsubj ['was']
# was VERB was was ROOT []
# huge ADJ was was acomp ['was']
# and CCONJ was was cc ['was']
# the DET service was det ['service', 'was', 'was']
# service NOUN was was nsubj ['was', 'was']
# was VERB was was conj ['was']
# so ADV bad was advmod ['bad', 'was', 'was']
# bad ADJ was was acomp ['was', 'was']

# %%
import nltk
import benepar
benepar.download('benepar_en2')
parser = benepar.Parser('benepar_en2')
text = reviews[0]['text']
tree = parser.parse(text)
print("Tree")
print(tree)
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-11-7b2bf9a9d939> in <module>
#       2 import benepar
#       3 #benepar.download('benepar_en2')
# ----> 4 parser = benepar.Parser('benepar_en2')
#       5 text = reviews[0]['text']
#       6 tree = parser.parse(text)
#
# ~/anaconda3/lib/python3.7/site-packages/benepar/nltk_plugin.py in __init__(self, name, batch_size)
#      34         batch_size (int): Maximum number of sentences to process per batch
#      35         """
# ---> 36         super(Parser, self).__init__(name, batch_size)
#      37         self._tokenizer_lang = TOKENIZER_LOOKUP.get(self._language_code, None)
#      38
#
# ~/anaconda3/lib/python3.7/site-packages/benepar/base_parser.py in __init__(self, name, batch_size)
#     178         with self._graph.as_default():
#     179             if isinstance(name, STRING_TYPES) and '/' not in name:
# --> 180                 model = load_model(name)
#     181             elif not os.path.exists(name):
#     182                 raise Exception("Argument is neither a valid module name nor a path to an existing file/folder: {}".format(name))
#
# ~/anaconda3/lib/python3.7/site-packages/benepar/downloader.py in load_model(name)
#      31         else:
#      32             return {
# ---> 33                 'meta': json.loads(nltk.data.load(name_zip + "/meta.json", format="text")),
#      34                 'model': nltk.data.load(name_zip + "/model.pb", format="raw"),
#      35                 'vocab': nltk.data.load(name_zip + "/vocab.txt", format="text", encoding="utf-8"),
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     866
#     867     # Load the resource.
# --> 868     opened_resource = _open(resource_url)
#     869
#     870     if format == 'raw':
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/data.py in _open(resource_url)
#     991
#     992     if protocol is None or protocol.lower() == 'nltk':
# --> 993         return find(path_, path + ['']).open()
#     994     elif protocol.lower() == 'file':
#     995         # urllib might not use mode='rb', so handle this one ourselves:
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/data.py in find(resource_name, paths)
#     658                 if os.path.exists(p):
#     659                     try:
# --> 660                         return ZipFilePathPointer(p, zipentry)
#     661                     except IOError:
#     662                         # resource not in zipfile
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/compat.py in _decorator(*args, **kwargs)
#     226     def _decorator(*args, **kwargs):
#     227         args = (args[0], add_py3_data(args[1])) + args[2:]
# --> 228         return init_func(*args, **kwargs)
#     229
#     230     return wraps(init_func)(_decorator)
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/data.py in __init__(self, zipfile, entry)
#     504         """
#     505         if isinstance(zipfile, string_types):
# --> 506             zipfile = OpenOnDemandZipFile(os.path.abspath(zipfile))
#     507
#     508         # Check that the entry exists:
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/compat.py in _decorator(*args, **kwargs)
#     226     def _decorator(*args, **kwargs):
#     227         args = (args[0], add_py3_data(args[1])) + args[2:]
# --> 228         return init_func(*args, **kwargs)
#     229
#     230     return wraps(init_func)(_decorator)
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/data.py in __init__(self, filename)
#    1053         if not isinstance(filename, string_types):
#    1054             raise TypeError('ReopenableZipFile filename must be a string')
# -> 1055         zipfile.ZipFile.__init__(self, filename)
#    1056         assert self.filename == filename
#    1057         self.close()
#
# ~/anaconda3/lib/python3.7/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1223         try:
#    1224             if mode == 'r':
# -> 1225                 self._RealGetContents()
#    1226             elif mode in ('w', 'x'):
#    1227                 # set the modified flag so central directory gets written
#
# ~/anaconda3/lib/python3.7/zipfile.py in _RealGetContents(self)
#    1290             raise BadZipFile("File is not a zip file")
#    1291         if not endrec:
# -> 1292             raise BadZipFile("File is not a zip file")
#    1293         if self.debug > 1:
#    1294             print(endrec)
#
# BadZipFile: File is not a zip file
